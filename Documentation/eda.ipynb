# %%
print("Hallo", "World")
# Out:
# Hallo World

# %% [markdown]
# # Task Day 1
#
# 1. Download CSV
# 2. Load into notebook using pandas
# 3. clean the csv
# 4. output clean files

# %%
# Function to calcualte the differnece bewteen the two date columns
# Try usins SQLAlchemy to write clean sules to SSMS

# %% [markdown]
# # Task Day 2
#
# 1. Make sur
