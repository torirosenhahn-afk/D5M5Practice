# %%
print("Hallo", "World")
# Out:
# Hallo World

# %% [markdown]
# # Task Day 1
#
# 1. Download CSV
# 2. Load into notebook using pandas
# 3. clean the csv
# 4. output clean files

# %%
# Function to calcualte the differnece bewteen the two date columns
# Try usins SQLAlchemy to write clean data to SSMS

# %% [markdown]
# # Task Day 2
#
# 1. Make sure your cleaning uses one or more functions, Must have a function to enrich the data (a function that works out the difference in days beterrn the date columns)
# 2. Turn your notebook into a executable .py file (manually)

# %% [markdown]
# Best practice - instaling liabaries
#
# 1. Create requirements.txt file with your dependancies
# 2. Create a venv using: pyhtion -m venv venv
# 3. Activating using: .\venv\scrips\activate.ps1
# 4. Install the depenancies using pip install -r Requirements.txt

# %% [markdown]
# Day 3
#
# Task 3:
# Create a docker container that uses the Calculator we built yesterday to output the answer to  145/12.
#
# Task 2:
# Turn your python app for data cleaning into a docker container that OUTPUTS the cleaned data in the (print)terminal. (containter has nothing in it to begin with)

# %% [markdown]
# Afternoon:
# Task 1: save files to volumes
# Task 2 read from volume
